# %% [markdown]
# # 03. Modèle ML : Changepoint Detection (PELT)
# Application de l'algorithme PELT (Pruned Exact Linear Time) pour détecter les ruptures de ton avec la librairie `ruptures`.

# %%
import ruptures as rpt
import numpy as np
import plotly.graph_objects as go

# Simulation pour la mise en place du modèle :
print("⏳ Modélisation Changepoint Detection avec 'ruptures' en attente de la série temporelle du ton moyen...")
