# %% [markdown]
# # 02. Feature Engineering & Nettoyage
# Analyse thématique, cartographie des événements, et identification des acteurs les plus mentionnés.

# %%
import pandas as pd
import folium
import seaborn as sns
import matplotlib.pyplot as plt

# Simulation
print("⏳ Prêt à entamer le nettoyage et la cartographie dès réception des données brutes...")

# df_gkg = pd.read_csv('../data/raw/benin_gkg.csv')

# %%
# Dictionnaire de classification thématique sur-mesure (Contexte Bénin 2025)
# GDELT va nous renvoyer des centaines de thèmes. Nous allons les regrouper 
# dans ces méta-catégories basées sur notre expertise métier.

categories_metier = {
    'Tourisme & Soft Power (Vodun, Culture)': ['TOURISM', 'CULTURE', 'ARTS', 'ENTERTAINMENT', 'SOCIETY'],
    'Crise Politique (Tentative Putsch, Opposants)': ['TREASON', 'REBELLION', 'PROTEST', 'ELECTION', 'HUMAN_RIGHTS'],
    'Sécurité & AES (Nord, Terrorisme)': ['TERROR', 'ARMED_CONFLICT', 'MILITARY', 'BORDER', 'EXTREMISM'],
    'Économie & Infrastructures': ['ECON_GROWTH', 'BUSINESS', 'INVESTMENT', 'TRADE', 'INFRASTRUCTURE']
}

print("✅ Dictionnaire des Méta-Catégories initialisé pour le filtrage du GKG.")
